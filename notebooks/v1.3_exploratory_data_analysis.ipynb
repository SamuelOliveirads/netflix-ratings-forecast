# %% [markdown]
# # 0.0 Imports

# %%
import warnings
import pandas as pd
import sweetviz as sv
import seaborn as sns

from tabulate import tabulate
from matplotlib import pyplot as plt
from pycorrcat import pycorrcat

# %% [markdown]
# ## 0.1 Load data

# %%
feature_engineering = catalog.load("feature_engineering")
# Out:
# [09/22/23 10:32:57] INFO     Loading data from 'feature_engineering' (CSVDataSet)...            ]8;id=593117;file://f:\SamuelOliveiraAlvesd\Anaconda3\envs\netflix_classifier\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=380001;file://f:\SamuelOliveiraAlvesd\Anaconda3\envs\netflix_classifier\Lib\site-packages\kedro\io\data_catalog.py#492\492]8;;\

# %% [markdown]
# ## 0.2 Helper Functions

# %%
def notebook_settings():
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', 60)
    pd.set_option('display.float_format', lambda x: '%.3f' % x)

    plt.style.use('bmh')
    plt.rcParams['figure.figsize'] = [25,12]
    plt.rcParams['font.size'] = 24
    sns.set()
    warnings.filterwarnings('ignore')
    return None


notebook_settings()

# %% [markdown]
# # 4.0 Exploratory Data Analysis

# %%
exploratory_data_analysis = feature_engineering.copy()

exploratory_data_analysis.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80125979  Movie                             #realityhigh
# 2  70304989  Movie                                 Automata
# 3  80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 4  70304990  Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                 Fernando Lebrija
# 2                      Gabe Ibáñez
# 3  Rodrigo Toro, Francisco Schultz
# 4                Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 2  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 3                                    Fabrizio Copano
# 4  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
#                                           country  date_added  release_year  \
# 0        United States, India, South Korea, China  2019-09-09          2019
# 1                                   United States  2017-09-08          2017
# 2          Bulgaria, United States, Spain, Canada  2017-09-08          2014
# 3                                           Chile  2017-09-08          2017
# 4  United States, United Kingdom, Denmark, Sweden  2017-09-08          2014
#
#    rating duration                                          listed_in  \
# 0      41   90 min                 Children & Family Movies, Comedies
# 1      57   99 min                                           Comedies
# 2      61  110 min  International Movies, Sci-Fi & Fantasy, Thrillers
# 3      49   60 min                                    Stand-Up Comedy
# 4      56   90 min                      Action & Adventure, Thrillers
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# 1  When nerdy high schooler Dani finally attracts...
# 2  In a dystopian future, an insurance adjuster f...
# 3  Fabrizio Copano takes audience participation t...
# 4  A struggling couple can't believe their luck w...

# %% [markdown]
# ## 4.1 Univariate Analysis

# %% [markdown]
# It is not necessary to execute the code, you can check the result in `/docs/SWEETVIZ_REPORT.html`.

# %%
# # We will use sweetviz for univariate automated analysis
# my_report = sv.analyze(exploratory_data_analysis)
# my_report.show_html(filepath='../docs/SWEETVIZ_REPORT.html', layout='widescreen')

# %% [markdown]
# ### 4.1.1 Sweetviz's main analyses

# %% [markdown]
# Sweetviz is a powerful tool for automating analysis. The result is made up of several graphs which can be overwhelming to consult. For now, I'm highlighting the main information extracted, but it would be interesting to enrich this session with graphs in a second version:

# %% [markdown]
# ### 4.1.2 Response Variable

# %% [markdown]
# ## 4.2 Bivariate Analysis

# %% [markdown]
# ### 4.2.1 Summary of Hypotheses

# %%
tab = [['Hypothesis', 'Conclusion'],
       ['H1', ''],
       ['H2', ''],
       ['H3', ''],
       ['H4', ''],
       ['H5', ''],
      ]
print(tabulate(tab, headers='firstrow'))
# Out:
# Hypothesis    Conclusion
# ------------  ------------
# H1
# H2
# H3
# H4
# H5

# %% [markdown]
# ## 4.3 Multivariate Analysis

# %% [markdown]
# ### 4.3.1 Numerical Attributes

# %%
num_attributes = exploratory_data_analysis.select_dtypes(include='number')

correlation = num_attributes.corr(method='pearson')
sns.heatmap(correlation, annot=True);
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2500x1200 with 2 Axes>

# %% [markdown]
# ### 4.3.2 Categorical Attributes

# %%
# only categorical data
cat_attributes = exploratory_data_analysis.select_dtypes(include='object')

# Cramer V correlation
correlation = pycorrcat.corr_matrix(cat_attributes, list(cat_attributes.columns))
sns.heatmap(correlation, annot=True);
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2500x1200 with 2 Axes>

# %%
catalog.save("exploratory_data_analysis", exploratory_data_analysis)
# Out:
# [09/22/23 10:34:12] INFO     Saving data to 'exploratory_data_analysis' (CSVDataSet)...         ]8;id=955784;file://f:\SamuelOliveiraAlvesd\Anaconda3\envs\netflix_classifier\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=573444;file://f:\SamuelOliveiraAlvesd\Anaconda3\envs\netflix_classifier\Lib\site-packages\kedro\io\data_catalog.py#531\531]8;;\
